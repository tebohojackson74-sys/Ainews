# %% [markdown]
# # Template analysis notebook
#
# This notebook is a template for reproducible analyses used by AINN data journalists. Replace cells below with your analysis steps. Include dataset links in the metadata and a reproducibility checklist.

# %%
# Example: load libraries
import pandas as pd
import numpy as np

# Load data (replace with path to processed CSV)
# df = pd.read_csv('../data/processed/example.csv')
# df.head()
